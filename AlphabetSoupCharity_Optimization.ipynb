# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# ...

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(['NAME'], axis=1)
application_df.head()
# Out:
#         EIN APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0  10520599              T10       Independent          C1000    ProductDev
# 1  10531628               T3       Independent          C2000  Preservation
# 2  10547893               T5  CompanySponsored          C3000    ProductDev
# 3  10553066               T3  CompanySponsored          C2000  Preservation
# 4  10556103               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# ...

# %%
# Look at APPLICATION_TYPE value counts to identify and replace with "Other"
application_counts = application_df['APPLICATION_TYPE'].value_counts()
application_counts
# Out:
# APPLICATION_TYPE
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
#USING SMALLER NUMBER FOR 1st optimization round
application_types_to_replace = list(application_counts[application_counts<50].index)

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure replacement was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# APPLICATION_TYPE
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# T9         156
# T13         66
# Other       54
# Name: count, dtype: int64

# %%
# Look at CLASSIFICATION value counts to identify and replace with "Other"
classification_counts = application_df["CLASSIFICATION"].value_counts()
classification_counts
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: count, Length: 71, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
# USING SMALLER NUMBER FOR OPTIMIZATION attempt 1, ATTEMPT 2, lowering number again
classifications_to_replace = list(classification_counts[classification_counts < 50].index)

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure replacement was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# Other      391
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# Name: count, dtype: int64

# %%
X_encoded = pd.get_dummies(application_df, dtype=int)
X_encoded
# Out:
#              EIN  STATUS   ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0       10520599       1      5000              1                       0
# 1       10531628       1    108590              1                       0
# 2       10547893       1      5000              0                       0
# 3       10553066       1      6692              1                       0
# 4       10556103       1    142590              1                       0
# ...          ...     ...       ...            ...                     ...
# 34294  996009318       1      5000              0                       0
# 34295  996010315       1      5000              0                       0
# 34296  996012607       1      5000              0                       0
# 34297  996015768       1      5000              1                       0
# 34298  996086871       1  36500179              0                       0
#
#        APPLICATION_TYPE_T10  APPLICATION_TYPE_T13  APPLICATION_TYPE_T19  \
# ...

# %%
# Split our preprocessed data into our features and target arrays
y = X_encoded["IS_SUCCESSFUL"]
X = X_encoded.drop(columns=["IS_SUCCESSFUL"])
# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=1)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
## ADDING MORE NEURONS AND ADDITIONAL LAYER FOR OPTIMIZATION, also changed activation
## THIRD OPTIMIZATION INCREASED NEURONS, switched all activations

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=100,activation='relu',input_dim=56))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=100,activation='swish'))

# Third hidden layer
nn.add(tf.keras.layers.Dense(units=50,activation='relu'))

# Output layer
nn.add(tf.keras.layers.Dense(units=1,activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_12 (Dense)            (None, 100)               5700
#
#  dense_13 (Dense)            (None, 100)               10100
#
#  dense_14 (Dense)            (None, 50)                5050
#
#  dense_15 (Dense)            (None, 1)                 51
#
# ...
# Total params: 20901 (81.64 KB)
# Trainable params: 20901 (81.64 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
# Train the model # USING LESS EPOCHS TO CUT DOWN ON TIME
fit_model = nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 3s 2ms/step - loss: 0.5658 - accuracy: 0.7220
# Epoch 2/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5492 - accuracy: 0.7303
# Epoch 3/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5466 - accuracy: 0.7319
# Epoch 4/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5431 - accuracy: 0.7337
# Epoch 5/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5419 - accuracy: 0.7362
# Epoch 6/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5404 - accuracy: 0.7348
# Epoch 7/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5388 - accuracy: 0.7364
# Epoch 8/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5379 - accuracy: 0.7364
# Epoch 9/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5362 - accuracy: 0.7374
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
# FIRST OPTIMIZATION ACCURACY = .7308
# SECOND OPTIMIZATION ACCURACY = .7329
# THIRD OPTIMIZATION ACCURACY = .7322
# FOURTH OPTIMIZATION ACCURACY = .7300
 # FIFTH OPTIMIZATION ACCURACY = .7297
 #FIFTH/ dropped additional columns, added more neurons and readjusted activation
 #6th optimization dropped NAME and kept EIN
 # SIXTH OPTIMIZTION ACCURACY = .7335, it did get up to .76 by the last epoch
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5906 - accuracy: 0.7301 - 499ms/epoch - 2ms/step
# Loss: 0.5905593037605286, Accuracy: 0.7301457524299622

# %%
# Export our model to HDF5 file
nn.save("AlphabetSoupCharity_optimization.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
